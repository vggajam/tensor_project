# %% [markdown]
# <a href="https://colab.research.google.com/github/vggajam/tensor_project/blob/main/tensor_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import os
from itertools import product as cart_prod
from math import sqrt

import matplotlib.pyplot as plt
import numpy as np
from scipy.io import loadmat
from scipy.fftpack import dct

# %%
# --- Tensor Completion using Transformed Phi-Product (t-SVD_phi) ---

def apply_phi_transform(tensor, UU):
    n1, n2, n3 = tensor.shape
    transformed = np.zeros_like(tensor)
    for i in range(n1):
        for j in range(n2):
            transformed[i, j, :] = UU @ tensor[i, j, :]
    return transformed

def apply_phi_inverse(tensor, UU):
    n1, n2, n3 = tensor.shape
    inverse = np.zeros_like(tensor)
    for i in range(n1):
        for j in range(n2):
            inverse[i, j, :] = UU.T @ tensor[i, j, :]
    return inverse

def phi_product(A, B, UU):
    assert A.shape[1] == B.shape[0], "Inner tensor dimensions must match."
    assert A.shape[2] == B.shape[2] == UU.shape[0], "Transform dimension mismatch."
    A_phi = apply_phi_transform(A, UU)
    B_phi = apply_phi_transform(B, UU)
    n1, _, n3 = A.shape
    _, n4, _ = B.shape
    C_phi = np.zeros((n1, n4, n3))
    for k in range(n3):
        C_phi[:, :, k] = A_phi[:, :, k] @ B_phi[:, :, k]
    return apply_phi_inverse(C_phi, UU)

def phi_transpose(tensor):
    return np.transpose(tensor, (1, 0, 2))

def phi_svd(tensor, UU):
    n1, n2, n3 = tensor.shape
    tensor_phi = apply_phi_transform(tensor, UU)
    U_phi = np.zeros((n1, n1, n3))
    S_phi = np.zeros((n1, n2, n3))
    V_phi = np.zeros((n2, n2, n3))
    for k in range(n3):
        U_k, S_k, Vh_k = np.linalg.svd(tensor_phi[:, :, k], full_matrices=False)
        U_phi[:, :, k] = U_k
        S_phi[:, :, k] = np.diag(S_k)
        V_phi[:, :, k] = Vh_k
    U = apply_phi_inverse(U_phi, UU)
    S = apply_phi_inverse(S_phi, UU)
    V = apply_phi_inverse(V_phi, UU)
    return U, S, V

def prox_l1(X, tau):
    return np.sign(X) * np.maximum(np.abs(X) - tau, 0)

def prox_ttnn(X, UU, rho):
    n1, n2, n3 = X.shape
    # Transform tensor to matrix format
    X_mat = np.reshape(np.transpose(X, (2, 0, 1)), (n3, n1 * n2))
    # Apply unitary transform
    X_transformed = UU.T @ X_mat
    # Reshape back to tensor format
    X_tensor = np.transpose(np.reshape(X_transformed, (n3, n1, n2)), (1, 2, 0))
    Y_tensor = np.zeros_like(X_tensor)
    for i in range(n3):
        U, S, Vh = np.linalg.svd(X_tensor[:, :, i], full_matrices=False)
        S_thresh = np.maximum(S - rho, 0)
        r = np.sum(S_thresh > 0)
        S_trunc = S_thresh[:r]
        Y_tensor[:, :, i] = U[:, :r] @ np.diag(S_trunc) @ Vh[:r, :]
    # Transform back to original space
    Y_mat = np.reshape(np.transpose(Y_tensor, (2, 0, 1)), (n3, n1 * n2))
    X_back = UU @ Y_mat
    X_result = np.transpose(np.reshape(X_back, (n3, n1, n2)), (1, 2, 0))
    return X_result

def tensor_complete_t_svd_data(X, UU, Omega, dim, tol=1e-4, beta=0.01, MaxIte=200, mu=1e-2, gamma=1.0, Z0=None, L0=None, E0=None):
    if L0 is None: L0 = np.zeros(dim)
    if E0 is None: E0 = np.zeros(dim)
    if Z0 is None: Z0 = np.zeros(dim)
    BarOmega = 1 - Omega
    aaa = []
    eta = None
    for k in range(1, MaxIte + 1):
        print(f"Iteration {k}...")
        Mbar = L0 + E0 - Z0 / beta
        Mbar = X * Omega + Mbar * BarOmega
        L = prox_ttnn(Mbar + Z0 / beta - E0, UU, 1 / beta)
        M = L + E0 - Z0 / beta
        M = X * Omega + M * BarOmega
        E = prox_l1(M + Z0 / beta - L, mu / beta)
        Z = Z0 - gamma * beta * (L + E - M)
        if k % 5 == 0 or k == MaxIte:
            etax = np.linalg.norm((L - prox_ttnn(L + Z, UU, 1)).ravel()) / (1 + np.linalg.norm(Z.ravel()) + np.linalg.norm(L.ravel()))
            etae = np.linalg.norm((E - prox_l1(Z + E, mu)).ravel()) / (1 + np.linalg.norm(Z.ravel()) + np.linalg.norm(E.ravel()))
            etap = np.linalg.norm((L + E - M).ravel()) / (1 + np.linalg.norm(L.ravel()) + np.linalg.norm(M.ravel()) + np.linalg.norm(E.ravel()))
            aaa = [etax, etae, etap]
            eta = max(aaa)
            print(f"  etax={etax:.2e}, etae={etae:.2e}, etap={etap:.2e}, eta={eta:.2e}")
            if eta <= tol:
                print(f"  ✅ Converged at iteration {k} with eta={eta:.2e}")
                break
        L0, E0, Z0 = L, E, Z
    return L, E, k, eta, aaa

# %%
# --- Tensor Completion with t-SVD using FFT ---


def t_transpose(tensor):
    """
    Tensor transpose (used in t-SVD): transpose each frontal slice.
    """
    return np.transpose(tensor, (1, 0, 2))

def t_product(A, B):
    """
    Compute the t-product of two 3D tensors A and B using FFT.
    """
    assert A.shape[2] == B.shape[2], "Tubes (3rd dim) must match"

    A_fft = np.fft.fft(A, axis=2)
    B_fft = np.fft.fft(B, axis=2)

    n1, _, n3 = A.shape
    _, n4, _ = B.shape
    C_fft = np.zeros((n1, n4, n3), dtype=complex)

    for i in range(n3):
        C_fft[:, :, i] = A_fft[:, :, i] @ B_fft[:, :, i]

    return np.fft.ifft(C_fft, axis=2).real

def prox_l1(X, tau):
    """
    Proximal operator for L1 norm (soft thresholding).
    """
    return np.sign(X) * np.maximum(np.abs(X) - tau, 0)

def prox_tnn(Y, rho):
    """
    Proximal operator of the tensor nuclear norm (TNN) of a 3D tensor.
    Implements the algorithm based on t-SVD using FFT (translated from MATLAB).

    Parameters:
        Y   : Input tensor (3D)
        rho : Threshold parameter

    Returns:
        X    : Low-rank approximated tensor
        tnn  : Tensor nuclear norm
        trank: Tensor tubal rank
    """
    n1, n2, n3 = Y.shape
    Y_fft = np.fft.fft(Y, axis=2)
    X_fft = np.zeros_like(Y_fft, dtype=complex)
    tnn = 0
    trank = 0

    halfn3 = int(np.floor(n3 / 2))

    # First frontal slice
    U, S, Vh = np.linalg.svd(Y_fft[:, :, 0], full_matrices=False)
    S_thresh = np.maximum(S - rho, 0)
    r = np.sum(S_thresh > 0)
    X_fft[:, :, 0] = (U[:, :r] @ np.diag(S_thresh[:r]) @ Vh[:r, :])
    tnn += np.sum(S_thresh)
    trank = max(trank, r)

    # 2 to halfn3
    for i in range(1, halfn3):
        U, S, Vh = np.linalg.svd(Y_fft[:, :, i], full_matrices=False)
        S_thresh = np.maximum(S - rho, 0)
        r = np.sum(S_thresh > 0)
        X_fft[:, :, i] = (U[:, :r] @ np.diag(S_thresh[:r]) @ Vh[:r, :])
        X_fft[:, :, n3 - i] = np.conj(X_fft[:, :, i])
        tnn += 2 * np.sum(S_thresh)
        trank = max(trank, r)

    # Handle center slice if n3 is even
    if n3 % 2 == 0:
        i = halfn3
        U, S, Vh = np.linalg.svd(Y_fft[:, :, i], full_matrices=False)
        S_thresh = np.maximum(S - rho, 0)
        r = np.sum(S_thresh > 0)
        X_fft[:, :, i] = (U[:, :r] @ np.diag(S_thresh[:r]) @ Vh[:r, :])
        tnn += np.sum(S_thresh)
        trank = max(trank, r)

    tnn = tnn / n3
    X = np.fft.ifft(X_fft, axis=2).real
    return X

def tensor_complete_t_svd_fourier(X, Omega, dim, tol=1e-4, beta=0.01, MaxIte=200, mu=1e-2, gamma=1.0, Z0=None, L0=None, E0=None):
    """
    Robust tensor completion using t-SVD in the Fourier domain.
    """
    if L0 is None: L0 = np.zeros(dim)
    if E0 is None: E0 = np.zeros(dim)
    if Z0 is None: Z0 = np.zeros(dim)

    BarOmega = 1 - Omega
    aaa = []
    eta = None

    for k in range(1, MaxIte + 1):
        print(f"Iteration {k}...")

        Mbar = L0 + E0 - Z0 / beta
        Mbar = X * Omega + Mbar * BarOmega

        L = prox_tnn(Mbar + Z0 / beta - E0, 1 / beta)
        M = L + E0 - Z0 / beta
        M = X * Omega + M * BarOmega
        E = prox_l1(M + Z0 / beta - L, mu / beta)
        Z = Z0 - gamma * beta * (L + E - M)

        if k % 5 == 0 or k == MaxIte:
            etax = np.linalg.norm((L - prox_tnn(L + Z, 1)).ravel()) / (1 + np.linalg.norm(Z.ravel()) + np.linalg.norm(L.ravel()))
            etae = np.linalg.norm((E - prox_l1(Z + E, mu)).ravel()) / (1 + np.linalg.norm(Z.ravel()) + np.linalg.norm(E.ravel()))
            etap = np.linalg.norm((L + E - M).ravel()) / (1 + np.linalg.norm(L.ravel()) + np.linalg.norm(M.ravel()) + np.linalg.norm(E.ravel()))

            aaa = [etax, etae, etap]
            eta = max(aaa)
            print(f"  etax={etax:.2e}, etae={etae:.2e}, etap={etap:.2e}, eta={eta:.2e}")

            if eta <= tol:
                print(f"  ✅ Converged at iteration {k} with eta={eta:.2e}")
                break

        L0, E0, Z0 = L, E, Z

    return L, E, k, eta, aaa

# %%
def psnr(rim, im):
    """
    Calculate a simplified PSNR (based on image size and squared error).
    This version matches the MATLAB logic.

    Parameters:
        rim : np.ndarray - reconstructed image
        im  : np.ndarray - original image

    Returns:
        p : float - PSNR-like value
    """
    # Flatten and compute squared error
    error = np.linalg.norm(rim.ravel() - im.ravel()) ** 2

    # Compute the PSNR-like metric
    p = 10 * (np.log10(im.shape[0] * im.shape[1]* im.shape[2]) - np.log10(error))
    return p


def get_unitary_from_mode3(X):
    """
    Compute a unitary matrix U ∈ ℂ^{n3 × n3} from the mode-3 unfolding of tensor X

    Parameters:
        X : ndarray of shape (n1, n2, n3)

    Returns:
        U : Unitary matrix of shape (n3, n3)
    """
    n1, n2, n3 = X.shape

    # Mode-3 unfolding: reshape to (n3, n1 * n2)
    unfolded = np.reshape(np.transpose(X, (2, 0, 1)), (n3, n1 * n2))

    # Perform SVD on the unfolded matrix (shape: n3 x (n1*n2))
    # This will give U ∈ ℂ^{n3 × n3} if n3 <= n1 * n2
    U, _, _ = np.linalg.svd(unfolded, full_matrices=False)

    # Return the first n3 columns to ensure square unitary matrix
    return U[:, :n3]


def save_4_bands_vertical(img, bands, filename='bands_4x1.png', cmap='gray'):
    """
    Save 4 hyperspectral bands vertically stacked (4x1 layout).
    
    Parameters:
        img       : np.ndarray (H, W, B) hyperspectral cube
        bands     : list of 4 integers (band indices)
        save_path : file path to save (e.g., 'bands.png')
        cmap      : matplotlib colormap (default: gray)
    """
    assert len(bands) == 4, "Provide exactly 4 band indices."

    fig, axs = plt.subplots(4, 1, figsize=(6, 12))  # 4 rows, 1 column
    axs = axs.ravel()

    for i, band in enumerate(bands):
        axs[i].imshow(img[:, :, band], cmap=cmap)
        axs[i].set_title(f'Band {band}', fontsize=12)
        axs[i].axis('off')

    plt.tight_layout()
    save_path = os.path.join("img", filename)
    plt.savefig(save_path, bbox_inches='tight')
    plt.close()
    print(f"Saved: {os.path.abspath(save_path)}")

# %%
def run_experiment(image_tensor, sparse_ratio_list, sampling_ratio_list, MaxIte=20, img_name="img"):

    XT = image_tensor / np.max(image_tensor)

    assert np.max(XT.ravel()) <= 1.0
    
    # Get tensor dimensions
    n1, n2, n3 = XT.shape
    dim = (n1, n2, n3)

    # Initial parameters
    beta = 0.05
    gamma = 1.618
    tol = 5e-4

    # Sparse corruption ratio (gamma in the paper)
    # SL = [0.1, 0.2, 0.3]

    # Initialize results container
    ZZ_list = []

    for jj in range(len(sparse_ratio_list)):
        sl_ratio = sparse_ratio_list[jj]

        # Generate sparse tensor corruption (binary mask with SL ratio)
        num_elements = n1 * n2 * n3
        num_sparse = int(sl_ratio * num_elements)
        sparse_mask = np.zeros(num_elements)
        sparse_mask[:num_sparse] = 1
        np.random.shuffle(sparse_mask)
        sparse_mask = sparse_mask.reshape((n1, n2, n3))

        # Create sparse corruption tensor with random noise
        STS = sparse_mask * np.random.randn(n1, n2, n3)

        # Add sparse noise to the clean tensor
        ZZ = XT + STS

        # Store for later if needed
        ZZ_list.append(ZZ.copy())

        save_4_bands_vertical(ZZ, bands=[10, 50, 100, 150], filename=f"{img_name}.scr[{sl_ratio}].png")


    # Sampling ratio (rho in the paper)
    # sr_list = [0.6, 0.8]

    omega_list = []
    for sr in sampling_ratio_list:
        # Generate observation mask Omega
        total_entries = n1 * n2 * n3
        num_observed = int(sr * total_entries)
        Omega_flat = np.zeros(total_entries)
        Omega_flat[:num_observed] = 1
        np.random.shuffle(Omega_flat)
        Omega = Omega_flat.reshape((n1, n2, n3))
        omega_list.append(Omega)

    result_data = []

    for sr_idx, sl_idx in cart_prod(range(len(sampling_ratio_list)), range(len(sparse_ratio_list))):

        sr = sampling_ratio_list[sr_idx]
        sl = sparse_ratio_list[sl_idx]
        # print(f"Sampling ratio = {sr:.8}")
        # print(f"Sparse corruption ratio = {sl:.8}")

        # Generate observation mask Omega
        Omega = omega_list[sr_idx]

        # Regularization parameter mu
        mu = 2 / np.sqrt(max(n1, n2) * n3)

        ZZ = ZZ_list[sl_idx].copy()
        X, E, fft_k, fft_eta, fft_aaa = tensor_complete_t_svd_fourier(ZZ, Omega, XT.shape, tol=tol, MaxIte=MaxIte, mu=mu, gamma=gamma)

        save_4_bands_vertical(X, bands=[10, 50, 100, 150], filename=f"{img_name}.scr[{sl}].sr[{sr}].fft.png")

        fft_error = np.linalg.norm(X.ravel()-XT.ravel())/np.linalg.norm(XT.ravel())
        print(f'FFT relative error = {fft_error:.8}')

        fft_PSNR = psnr(X,XT)
        print(f'FFT PSNR = {fft_PSNR:.8}')

        phi = get_unitary_from_mode3(X)
        ZZ = ZZ_list[sl_idx].copy()
        mu = 25 / np.sqrt(max(n1, n2) * n3)

        # print("phi shape",phi.shape)
        # L, E, k, eta, aaa
        XU, E, unitary_k, unitary_eta, unitary_aaa = tensor_complete_t_svd_data(ZZ, phi, Omega, XT.shape, tol=tol, beta=beta, MaxIte=MaxIte, mu=mu, gamma=gamma)

        save_4_bands_vertical(XU, bands=[10, 50, 100, 150], filename=f"{img_name}.scr[{sl}].sr[{sr}].unitary.png")

        unitary_error = np.linalg.norm(XU.ravel() - XT.ravel()) / np.linalg.norm(XT.ravel())
        # print(f"Unitary relative error = {unitary_error:.8e}")

        unitary_PSNR = psnr(XU, XT)
        # print(f"Unitary PSNR = {unitary_PSNR:.8e}")

        result_data.append({
            "sample_ratio": sr,
            "sparse_corruption_ratio":sl,
            "fft_relative_error": fft_error,
            "fft_psnr": fft_PSNR,
            "fft_k": fft_k,
            "fft_eta": fft_eta,
            "unitary_relative_error": unitary_error,
            "unitary_psnr":unitary_PSNR,
            "unitary_k": unitary_k,
            "unitary_eta": unitary_eta,
        })
        print(result_data[-1])

    return result_data

# %%
np.random.seed(2013)

filename_list = [
    "JasperRidge2_R198.mat", 
    # "Urban_R162.mat", 
    "Samson.mat",
]
for filename in filename_list:
    print(filename)
    mat_data = loadmat(f'dataset/hyperspectral/{filename}')
    YT = mat_data['Y'].T
    YT = YT.reshape(int(sqrt(YT.shape[0])),int(sqrt(YT.shape[0])),YT.shape[1])
    print("shape", YT.shape)
    
    save_4_bands_vertical(YT, bands=[10, 50, 100, 150], filename=f"{filename}.orig.png")

    sparse_ratios = [0.1, 0.2, 0.3]
    sampling_ratios = [0.6, 0.8]

    YT = YT/np.max(YT)
    print(np.max(YT.ravel()))

    error = np.linalg.norm(YT-YT)/np.linalg.norm(YT)
    print(error)
    results = run_experiment(YT, sparse_ratios, sampling_ratios, img_name=filename, MaxIte=500)

    with open(f"{filename}.json", "w") as f:
        json.dump(results, f)
# Out:
# JasperRidge2_R198.mat
# shape (100, 100, 198)
