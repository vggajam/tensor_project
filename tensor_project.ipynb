# %% [markdown]
# <a href="https://colab.research.google.com/github/vggajam/tensor_project/blob/main/tensor_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.io import loadmat
from itertools import product as cart_prod
import json
from math import sqrt

# %%
# phi-product utils

def apply_phi_transform(tensor, UU):
    """Apply unitary transform UU along 3rd mode"""
    n1, n2, n3 = tensor.shape
    transformed = np.zeros_like(tensor)
    for i in range(n1):
        for j in range(n2):
            transformed[i, j, :] = UU @ tensor[i, j, :]
    return transformed

def apply_phi_inverse(tensor, UU):
    """Apply inverse unitary transform UU^T along 3rd mode"""
    n1, n2, n3 = tensor.shape
    inverse = np.zeros_like(tensor)
    for i in range(n1):
        for j in range(n2):
            inverse[i, j, :] = UU.T @ tensor[i, j, :]
    return inverse

def phi_product(A, B, UU):
    """
    Multiply two tensors A and B using the Phi-product.

    Parameters:
        A: Tensor of shape (n1, n2, n3)
        B: Tensor of shape (n2, n4, n3)
        UU: Unitary transform matrix of shape (n3, n3)

    Returns:
        C = A *phi B, of shape (n1, n4, n3)
    """
    assert A.shape[1] == B.shape[0], "Tensor inner dimensions must match."
    assert A.shape[2] == B.shape[2] == UU.shape[0], "Transform dimension mismatch."

    # Step 1: Transform both tensors along mode-3
    A_phi = apply_phi_transform(A, UU)
    B_phi = apply_phi_transform(B, UU)

    n1, n2, n3 = A.shape
    _, n4, _ = B.shape
    C_phi = np.zeros((n1, n4, n3))

    # Step 2: Multiply frontal slices in transformed domain
    for k in range(n3):
        C_phi[:, :, k] = A_phi[:, :, k] @ B_phi[:, :, k]

    # Step 3: Inverse transform result
    C = apply_phi_inverse(C_phi, UU)
    return C

def phi_svd(tensor, UU):
    """
    Perform transformed tensor SVD using general unitary transform UU.
    Returns U, S, V such that: tensor ≈ U *phi S *phi V^T
    """

    # print(tensor.shape)
    n1, n2, n3 = tensor.shape

    # Step 1: Apply transform Phi along mode-3
    tensor_phi = apply_phi_transform(tensor, UU)

    U_phi = np.zeros((n1, n1, n3))
    S_phi = np.zeros((n1, n2, n3))
    V_phi = np.zeros((n2, n2, n3))

    # Step 2: SVD on each frontal slice in transform domain
    for k in range(n3):
        U_k, S_k, Vh_k = np.linalg.svd(tensor_phi[:, :, k], full_matrices=False)
        U_phi[:, :, k] = U_k
        S_phi[:, :, k] = np.diag(S_k)
        V_phi[:, :, k] = Vh_k

    # Step 3: Inverse transform Phi to get U, S, V
    U = apply_phi_inverse(U_phi, UU)
    S = apply_phi_inverse(S_phi, UU)
    V = apply_phi_inverse(V_phi, UU)

    return U, S, V

# t-SVD (Data) code

def prox_l1(X, tau):
    """Proximal operator for L1 norm (soft thresholding)"""
    return np.sign(X) * np.maximum(np.abs(X) - tau, 0)

def prox_ttnn(X, UU, tau):
    """
    Proximal operator for the Transformed Tubal Nuclear Norm (TTNN)
    using t-SVD in the Phi domain.

    Parameters:
        X   : Input tensor (3D)
        UU  : Unitary transform matrix (e.g., DCT, learned)
        tau : Threshold parameter (float)

    Returns:
        Thresholded tensor (3D) after applying TTNN shrinkage
    """
    # Step 1: Compute t-SVD in Phi domain
    # print(X.shape, UU.shape)
    U, S, V = phi_svd(X, UU)

    # Step 2: Soft-threshold the singular values
    # print(S.shape)
    n1, n2, n3 = S.shape
    for k in range(n3):
        s = np.diag(S[:, :, k])
        s_thresh = np.maximum(s - tau, 0)
        S[:, :, k] = np.diag(s_thresh)

    # Step 3: Reconstruct the tensor: U *phi S *phi V^T
    return phi_product(phi_product(U, S, UU), V, UU)

def tensor_complete_t_svd_data(X, UU, Omega, dim, tol=1e-4, beta=1e-2, MaxIte=500, mu=1e-2, gamma=1.6, Z0=None, L0=None, E0=None):

    # n1, n2, n3 = X.shape

    L0 = L0 if L0 else np.zeros(dim)
    E0 = E0 if E0 else np.zeros(dim)
    Z0 = Z0 if Z0 else np.zeros(dim)

    BarOmega = 1 - Omega
    aaa = []

    for k in range(1, MaxIte + 1):
        # print(f"Iter: {k}")

        # Update Mbar
        Mbar = L0 + E0 - Z0 / beta
        Mbar = X * Omega + Mbar * BarOmega

        # Update L using TTNN proximal operator
        L = prox_ttnn(Mbar + Z0 / beta - E0, UU, 1 / beta)

        # Update M
        M = L + E0 - Z0 / beta
        M = X * Omega + M * BarOmega

        # Update E using soft thresholding
        E = prox_l1(M + Z0 / beta - L, mu / beta)

        # Update Lagrange multiplier Z
        Z = Z0 - gamma * beta * (L + E - M)

        # Check convergence
        if k > 1:
            etax = L - prox_ttnn(L + Z, UU, 1)
            etax = np.linalg.norm(etax.ravel()) / (1 + np.linalg.norm(Z.ravel()) + np.linalg.norm(L.ravel()))

            etae = E - prox_l1(Z + E, mu)
            etae = np.linalg.norm(etae.ravel()) / (1 + np.linalg.norm(Z.ravel()) + np.linalg.norm(E.ravel()))

            etap = L + E - M
            etap = np.linalg.norm(etap.ravel()) / (1 + np.linalg.norm(L.ravel()) + np.linalg.norm(M.ravel()) + np.linalg.norm(E.ravel()))

            aaa = [etax, etae, etap]
            eta = max([etax, etae, etap])
            # print(f"eta={eta}")

            if eta <= tol:
                break

        L0, Z0, E0 = L, Z, E

    return L, E, aaa, k

# %%
# t-product utilities

def t_product(A, B):
    """
    Compute the t-product of two 3D tensors A and B using FFT.

    Parameters:
        A : np.ndarray of shape (n1, n2, n3)
        B : np.ndarray of shape (n2, n4, n3)

    Returns:
        C : np.ndarray of shape (n1, n4, n3), the t-product A * B
    """
    assert A.shape[1] == B.shape[0], "Inner tensor dimensions must match"
    assert A.shape[2] == B.shape[2], "3rd dimension (tubes) must match"

    n1, n2, n3 = A.shape
    _, n4, _ = B.shape

    # Step 1: FFT along the 3rd mode
    A_fft = np.fft.fft(A, axis=2)
    B_fft = np.fft.fft(B, axis=2)

    # Step 2: Slice-wise matrix multiplication
    C_fft = np.zeros((n1, n4, n3), dtype=complex)
    for i in range(n3):
        C_fft[:, :, i] = A_fft[:, :, i] @ B_fft[:, :, i]

    # Step 3: Inverse FFT along the 3rd mode
    C = np.fft.ifft(C_fft, axis=2)

    return C.real  # discard imaginary part (should be numerically negligible)

def t_svd_fft(tensor):
    """
    Compute the t-SVD of a 3D tensor using FFT along the 3rd dimension.

    Returns:
        U, S, V: tensors such that tensor ≈ U * S * V^T
    """
    n1, n2, n3 = tensor.shape

    # Step 1: Apply FFT along the 3rd mode
    tensor_fft = np.fft.fft(tensor, axis=2)

    # Step 2: Perform SVD on each frontal slice in the Fourier domain
    U_fft = np.zeros((n1, n1, n3), dtype=complex)
    S_fft = np.zeros((n1, n2, n3), dtype=complex)
    V_fft = np.zeros((n2, n2, n3), dtype=complex)

    for k in range(n3):
        U_k, S_k, Vh_k = np.linalg.svd(tensor_fft[:, :, k], full_matrices=False)
        U_fft[:, :, k] = U_k
        S_fft[:, :, k] = np.diag(S_k)
        V_fft[:, :, k] = Vh_k

    # Step 3: Apply inverse FFT to get U, S, V in original domain
    U = np.fft.ifft(U_fft, axis=2).real
    S = np.fft.ifft(S_fft, axis=2).real
    V = np.fft.ifft(V_fft, axis=2).real

    return U, S, V

# t-SVD (fourier) code

def prox_tnn(Y, tau):
    """
    Proximal operator for the Tubal Nuclear Norm (TNN)
    using t-SVD in the fourier domain.

    Parameters:
        Y   : Input tensor (3D)
        tau : Threshold parameter (float)

    Returns:
        Thresholded tensor (3D) after applying TNN shrinkage
    """
    # Step 1: Compute t-SVD in fft domain
    # print(Y.shape)
    U, S, V = t_svd_fft(Y)

    # Step 2: Soft-threshold the singular values
    n1, n2, n3 = S.shape
    for k in range(n3):
        s = np.diag(S[:, :, k])
        s_thresh = np.maximum(s - tau, 0)
        S[:, :, k] = np.diag(s_thresh)

    # Step 3: Reconstruct the tensor
    return t_product(t_product(U, S), V)

def tensor_complete_t_svd_fourier(X, Omega, dim, tol=1e-4, beta=0.01, MaxIte=500, mu=1e-2, gamma=1.618, Z0=None, L0=None, E0=None):
    """
    Robust tensor completion using Transformed Tensor SVD (t-SVD).
    Translated from MATLAB implementation in Song et al. (2020).

    Parameters:
        X : np.ndarray - observed tensor with missing values
        Omega : np.ndarray - binary mask (1 for observed entries, 0 for missing)
        dim : tuple - shape of the tensor
        opts : dict - contains optional parameters like beta, mu, gamma, etc.

    Returns:
        L : low-rank tensor
        E : sparse tensor
        k : number of iterations
        eta : final convergence metric
        aaa : convergence metrics [etax, etae, etap]
    """

    L0 = L0 if L0 else np.zeros(dim)
    E0 = E0 if E0 else np.zeros(dim)
    Z0 = Z0 if Z0 else np.zeros(dim)

    BarOmega = 1 - Omega
    aaa = []
    eta = None

    for k in range(1, MaxIte + 1):
        # print(f"iter={k}")

        # Update Mbar
        Mbar = L0 + E0 - Z0 / beta
        Mbar = X * Omega + Mbar * BarOmega

        # Update L using TTNN prox
        L = prox_tnn(Mbar + Z0 / beta - E0, 1 / beta)

        # Update M
        M = L + E0 - Z0 / beta
        M = X * Omega + M * BarOmega

        # Update E using L1 prox
        E = prox_l1(M + Z0 / beta - L, mu / beta)

        # Update Lagrange multiplier
        Z = Z0 - gamma * beta * (L + E - M)

        # Check convergence
        if k > 1:
            etax = L - prox_tnn(L + Z, 1)
            etax = np.linalg.norm(etax.ravel()) / (1 + np.linalg.norm(Z.ravel()) + np.linalg.norm(L.ravel()))

            etae = E - prox_l1(Z + E, mu)
            etae = np.linalg.norm(etae.ravel()) / (1 + np.linalg.norm(Z.ravel()) + np.linalg.norm(E.ravel()))

            etap = L + E - M
            etap = np.linalg.norm(etap.ravel()) / (1 + np.linalg.norm(L.ravel()) + np.linalg.norm(M.ravel()) + np.linalg.norm(E.ravel()))

            aaa = [etax, etae, etap]
            eta = max(aaa)
            # print(f"eta: {eta}")
            if eta <= tol:
                break

        # Prepare for next iteration
        L0 = L
        Z0 = Z
        E0 = E

    return L, E, k, eta, aaa

# %%
def psnr(rim, im):
    """
    Calculate a simplified PSNR (based on image size and squared error).
    This version matches the MATLAB logic.

    Parameters:
        rim : np.ndarray - reconstructed image
        im  : np.ndarray - original image

    Returns:
        p : float - PSNR-like value
    """
    # Flatten and compute squared error
    error = np.linalg.norm(rim.ravel() - im.ravel()) ** 2

    # Compute the PSNR-like metric
    p = 10 * (np.log10(im.shape[0] * im.shape[1]* im.shape[2]) - np.log10(error))
    return p


def get_unitary_from_mode3(X):
    """
    Compute a unitary matrix U ∈ ℂ^{n3 × n3} from the mode-3 unfolding of tensor X

    Parameters:
        X : ndarray of shape (n1, n2, n3)

    Returns:
        U : Unitary matrix of shape (n3, n3)
    """
    n1, n2, n3 = X.shape

    # Mode-3 unfolding: reshape to (n3, n1 * n2)
    unfolded = np.reshape(np.transpose(X, (2, 0, 1)), (n3, n1 * n2))

    # Perform SVD on the unfolded matrix (shape: n3 x (n1*n2))
    # This will give U ∈ ℂ^{n3 × n3} if n3 <= n1 * n2
    U, _, _ = np.linalg.svd(unfolded, full_matrices=True)

    # Return the first n3 columns to ensure square unitary matrix
    return U[:, :n3]

# %%
def run_experiment(image_tensor, sparse_ratio_list, sampling_ratio_list, MaxIte=20):

    XT = image_tensor / np.max(image_tensor)

    # Get tensor dimensions
    n1, n2, n3 = XT.shape
    dim = (n1, n2, n3)

    # Initial parameters
    beta = 0.05
    gamma = 1.618
    tol = 5e-4

    # Sparse corruption ratio (gamma in the paper)
    # SL = [0.1, 0.2, 0.3]

    # Initialize results container
    ZZ_list = []

    for jj in range(len(sparse_ratio_list)):
        sl_ratio = sparse_ratio_list[jj]

        # Generate sparse tensor corruption (binary mask with SL ratio)
        num_elements = n1 * n2 * n3
        num_sparse = int(sl_ratio * num_elements)
        sparse_mask = np.zeros(num_elements)
        sparse_mask[:num_sparse] = 1
        np.random.shuffle(sparse_mask)
        sparse_mask = sparse_mask.reshape((n1, n2, n3))

        # Create sparse corruption tensor with random noise
        STS = sparse_mask * np.random.randn(n1, n2, n3)

        # Add sparse noise to the clean tensor
        ZZ = XT + STS

        # Store for later if needed
        ZZ_list.append(ZZ.copy())


    # Sampling ratio (rho in the paper)
    # sr_list = [0.6, 0.8]

    omega_list = []
    for sr in sampling_ratio_list:
        # Generate observation mask Omega
        total_entries = n1 * n2 * n3
        num_observed = int(sr * total_entries)
        Omega_flat = np.zeros(total_entries)
        Omega_flat[:num_observed] = 1
        np.random.shuffle(Omega_flat)
        Omega = Omega_flat.reshape((n1, n2, n3))
        omega_list.append(Omega)

    result_data = []

    for sr_idx, sl_idx in cart_prod(range(len(sampling_ratio_list)), range(len(sparse_ratio_list))):

        sr = sampling_ratio_list[sr_idx]
        sl = sparse_ratio_list[sl_idx]
        # print(f"Sampling ratio = {sr:.8}")
        # print(f"Sparse corruption ratio = {sl:.8}")

        # Generate observation mask Omega
        Omega = omega_list[sr_idx]

        # Regularization parameter mu
        mu = 2 / np.sqrt(max(n1, n2) * n3)

        ZZ = ZZ_list[sl_idx].copy()
        X, E, fft_k, eta, fft_aaa = tensor_complete_t_svd_fourier(ZZ, Omega, XT.shape, tol=tol, MaxIte=MaxIte, mu=mu, gamma=gamma)

        fft_error = np.linalg.norm(X.ravel()-XT.ravel())/np.linalg.norm(XT.ravel())
        # print(f'FFT relative error = {fft_error:.8}')

        fft_PSNR = psnr(XT,X)
        # print(f'FFT PSNR = {fft_PSNR:.8}')

        phi = get_unitary_from_mode3(X)
        ZZ = ZZ_list[sl_idx].copy()
        mu = 25 / np.sqrt(max(n1, n2) * n3)

        # print("phi shape",phi.shape)
        XU, E, unitary_aaa, unitary_k = tensor_complete_t_svd_data(ZZ, phi, Omega, XT.shape, tol=tol, beta=beta, MaxIte=MaxIte, mu=mu, gamma=gamma)

        unitary_error = np.linalg.norm(XU.ravel() - XT.ravel()) / np.linalg.norm(XT.ravel())
        # print(f"Unitary relative error = {unitary_error:.8e}")

        unitary_PSNR = psnr(XU, XT)
        # print(f"Unitary PSNR = {unitary_PSNR:.8e}")

        result_data.append({
            "sample_ratio": sr,
            "sparse_corruption_ratio":sl,
            "fft_relative_error": fft_error,
            "fft_psnr": fft_PSNR,
            "fft_k": fft_k,
            "fft_eta": max(fft_aaa),
            "unitary_relative_error": unitary_error,
            "unitary_psnr":unitary_PSNR,
            "unitary_k": unitary_k,
            "unitary_eta": max(unitary_aaa),
        })
        print(result_data[-1])

    return result_data

# %%
filename = "Samson.mat"

mat_data = loadmat(f'dataset/hyperspectral/{filename}')
YT = mat_data['Y'].T
YT = YT.reshape(int(sqrt(YT.shape[0])),int(sqrt(YT.shape[0])),YT.shape[1])

sparse_ratios = [0.1, 0.2, 0.3]
sampling_ratios = [0.6, 0.8]

results = run_experiment(YT, sparse_ratios, sampling_ratios, MaxIte=2)

with open(f"{filename}.json", "w") as f:
    json.dump(results, f)
# Out:
# {'sample_ratio': 0.6, 'sparse_corruption_ratio': 0.1, 'fft_relative_error': np.float64(1.114749550516151), 'fft_psnr': np.float64(11.297181492562407), 'fft_k': 2, 'fft_eta': np.float64(0.2599035769014167), 'unitary_relative_error': np.float64(1.2237027310805948), 'unitary_psnr': np.float64(10.487209024640984), 'unitary_k': 2, 'unitary_eta': np.float64(0.5193384927728432)}
# {'sample_ratio': 0.6, 'sparse_corruption_ratio': 0.2, 'fft_relative_error': np.float64(1.5628180604849875), 'fft_psnr': np.float64(8.36255918182907), 'fft_k': 2, 'fft_eta': np.float64(0.21808147568974742), 'unitary_relative_error': np.float64(1.7481822863621375), 'unitary_psnr': np.float64(7.388993302942541), 'unitary_k': 2, 'unitary_eta': np.float64(0.2683793352278123)}
# ...
